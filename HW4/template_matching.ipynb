# %%
import cv2
from skimage.data import coins
import matplotlib.pyplot as plt

# %%
image = coins()
plt.imshow(image, cmap="gray")

# %%
smallCoin = coins()[37:37+38, 80:80+41] 
plt.imshow(smallCoin, cmap="gray")

# %%
largeCoin = coins()[14:14+59,302:302+65]
plt.imshow(largeCoin, cmap="gray")

# %% [markdown]
# **Template Matching**
#
# Use Python libraries (skimage , opencv , ...) to find matches with two template above.

# %% [markdown]
# show the found matches on coins image.

# %% [markdown]
# Your Implementation (Extra points)
